# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LiquidMercury-tech/flyrank-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# I am choosing Lane 4: CTR / Engagement Opportunity Scoring. This lane is worth the next 7 weeks because it turns a large content inventory into a practical review queue: pages that already have enough impressions and visibility to matter, but are under-capturing clicks or engagement. The action is concrete — a metadata refresh, better intent match, or a monitoring decision — so the output is immediately useful to editors without needing a full site redesign.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os
data_path = "data/raw/content_refresh_anonymized.csv"
print(f"Starter dataset path: {data_path}")
print("Target lane: Lane 4 - CTR / Engagement Opportunity Scoring")
# Out:
# Starter dataset path: data/raw/content_refresh_anonymized.csv
# Target lane: Lane 4 - CTR / Engagement Opportunity Scoring

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# This work improves the decision of which visible pages deserve editor attention first. The decision-maker is the content or SEO team, who can choose to refresh metadata, improve title/description intent match, or monitor a page instead of spending time on weaker candidates. A false positive wastes limited review capacity and a refresh budget on a page that was already healthy. A false negative misses an easy win: a visible page with enough demand to matter but weak CTR or engagement, which costs clicks, sessions, and conversion opportunity.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
decision = "Which visible pages deserve review first for CTR or engagement uplift?"
actor = "SEO/content editors and page owners"
wrong_call = {
    'false_positive': 'Waste review hours and refresh budget on a page that is already healthy',
    'false_negative': 'Miss a visible, high-demand page that under-captures clicks or engagement'
}
print(f"Decision: {decision}")
print(f"Actor: {actor}")
print(f"Wrong call cost: {wrong_call['false_positive']} / {wrong_call['false_negative']}")
# Out:
# Decision: Which visible pages deserve review first for CTR or engagement uplift?
# Actor: SEO/content editors and page owners
# Wrong call cost: Waste review hours and refresh budget on a page that is already healthy / Miss a visible, high-demand page that under-captures clicks or engagement

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# This starter slice has enough signal to be interesting. I am focusing on visible pages with real demand and position data because that is where a CTR or engagement opportunity model can help editors sort their review queue.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
from pathlib import Path
import pandas as pd

candidate_paths = [
    Path('data/raw/content_refresh_anonymized.csv'),
    Path.cwd() / 'data' / 'raw' / 'content_refresh_anonymized.csv',
    Path.cwd().parent / 'data' / 'raw' / 'content_refresh_anonymized.csv',
    Path.cwd().parent.parent / 'data' / 'raw' / 'content_refresh_anonymized.csv',
]
data_path = next((p for p in candidate_paths if p.exists()), None)
if data_path is None:
    raise FileNotFoundError('Could not locate data/raw/content_refresh_anonymized.csv')
df = pd.read_csv(data_path)
rows = len(df)
usable_position_rows = int((df['avg_position'] > 0).sum())
high_volume_low_ctr = int(((df['impressions_90d'] >= 500) & (df['avg_position'] > 0) & (df['avg_position'] <= 20) & (df['ctr'] < 0.5)).sum())
high_sessions_weak_engagement = int(((df['sessions_90d'] >= 30) & ((df['engagement_rate'] < 30) | (df['scroll_rate'] < 30))).sum())
print(f'Total rows in starter dataset: {rows}')
print(f'Visible pages with usable position data: {usable_position_rows}')
print(f'High-volume low-CTR pages (>=500 impressions, pos 1-20, CTR < 0.5): {high_volume_low_ctr}')
print(f'High-session pages with weak engagement: {high_sessions_weak_engagement}')
# Out:
# Total rows in starter dataset: 30000
# Visible pages with usable position data: 28795
# High-volume low-CTR pages (>=500 impressions, pos 1-20, CTR < 0.5): 9759
# High-session pages with weak engagement: 7113

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# This project can claim a data-driven, decision-support ranking of pages that show observed signs of under-capturing clicks or engagement. Using impressions, position, CTR, and engagement metrics, it can say which pages look like the strongest review candidates based on measured patterns. It cannot claim that a low-CTR title causes worse rankings, nor can it prove a metadata refresh will improve performance. This is observational work: strong for prioritization, not proof of causality or a claim about Google’s black box.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
claim_can = [
    'Observed CTR and engagement gaps on visible pages',
    'Directional ranking of review candidates by opportunity',
    'Decision-support output for editors'
]
claim_cannot = [
    'Causal proof that a title or metadata fix caused a later gain',
    'A claim about Google’s hidden ranking function',
    'A guarantee that every low-CTR page is worth editing'
]
print('This work can claim:')
for item in claim_can:
    print(f'- {item}')
print('\nThis work cannot claim:')
for item in claim_cannot:
    print(f'- {item}')
# Out:
# This work can claim:
# - Observed CTR and engagement gaps on visible pages
# - Directional ranking of review candidates by opportunity
# - Decision-support output for editors
#
# This work cannot claim:
# - Causal proof that a title or metadata fix caused a later gain
# - A claim about Google’s hidden ranking function
# - A guarantee that every low-CTR page is worth editing

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
